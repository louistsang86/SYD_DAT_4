# %% [markdown]
# # Introduction to Data Science with Python
# ## General Assembly - 22nd February 2016 Day 1##
# ## Natural Language Processing (NLP)
#
# This notebook contains exercises for getting started with Natual Language Processing in Python. The main topics we will cover in this class are:
# 1. Tokenizing
# 2. Stemming
# 3. Speech Tagging
# 4. Named Entity Recognition
# 5. Term Frequency - Inverse Document Frequency
# 6. Latent Dirichlet Allocation
#
# Other:
# - Analysing data with the Alchemy API
# - Further Reading

# %%
import nltk
nltk.download()

# %% [markdown]
# ###Tokenization
#
# What:  Separate text into units such as sentences or words
#
# Why:   Gives structure to previously unstructured text
#
# Notes: Relatively easy with English language text, not easy with some languages
#
#
# "corpus" = collection of documents
#
# "corpora" = plural form of corpus

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("http://en.wikipedia.org/wiki/Data_science")
b = BeautifulSoup(r.text)
paragraphs = b.find("body").findAll("p")
text = ""
for paragraph in paragraphs:
    text += paragraph.text + " "
# Data Science corpus
text[:500]
# Out:
# u'Data science is an interdisciplinary field about processes and systems to extract knowledge or insights from data in various forms, either structured or unstructured,[1][2] which is a continuation of some of the data analysis fields such as statistics, data mining, and predictive analytics, similar to Knowledge Discovery in Databases (KDD).   Data science employs techniques and theories drawn from many fields within the broad areas of mathematics, statistics, information science, and computer sc'

# %%
b
# Out:
# <!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n<head>\n<meta charset="unicode-escape"/>\n<title>Data science - Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Data_science","wgTitle":"Data science","wgCurRevisionId":719064235,"wgRevisionId":719064235,"wgArticleId":35458904,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 errors: external links","Pages using web citations with no URL","Use dmy dates from December 2012","All articles with unsourced statements","Articles with unsourced statements from July 2014","Commons category with local link same as on Wikidata","Information science","Computer occupations"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Data_science","wgRelevantArticleId":35458904,"wgRequestId":"Vy3LsgpAMFkAADH0qE4AAAAH","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSAcceptLanguageList":["en-us","en"],"wgULSCurrentAutonym":"English","wgFlaggedRevsParams":{"tags":{"status":{"levels":1,"quality":2,"pristine":3}}},"wgStableRevisionId":null,"wgCategoryTreePageCategoryOptions":"{\\"mode\\":0,\\"hideprefix\\":20,\\"showcount\\":true,\\"namespaces\\":false}","wgNoticeProject":"wikipedia","wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCentralAuthMobileDomain":false,"wgWikibaseItemId":"Q2374463","wgVisualEditorToolbarScrollOffset":0});mw.loader.implement("user.options",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens",function ( $, jQuery, require, module ) {\nmw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});/*@nomin*/;\n\n});mw.loader.load(["mediawiki.page.startup","mediawiki.legacy.wikibits","ext.centralauth.centralautologin","mmv.head","ext.visualEditor.desktopArticleTarget.init","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","mw.MediaWikiPlayer.loader","mw.PopUpMediaTransform","ext.centralNotice.bannerController","skins.vector.js"]);});</script>\n<link href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.gadget.DRN-wizard%2CReferenceTooltips%2Ccharinsert%2Cfeatured-articles-links%2CrefToolbar%2Cswitcher%2Cteahouse%7Cext.tmh.thumbnail.styles%7Cext.uls.nojs%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.raggett%2CsectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>\n<meta content="" name="ResourceLoaderDynamicStyles"/>\n<link href="/w/load.php?debug=false&amp;lang=en&amp;modules=site&amp;only=styles&amp;skin=vector" rel="stylesheet"/>\n<script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>\n<meta c ...

# %%
# tokenize into sentences
sentences = [sent for sent in nltk.sent_tokenize(text)]
sentences[:10]
# Out:
# [u'Data science is an interdisciplinary field about processes and systems to extract knowledge or insights from data in various forms, either structured or unstructured,[1][2] which is a continuation of some of the data analysis fields such as statistics, data mining, and predictive analytics, similar to Knowledge Discovery in Databases (KDD).',
#  u'Data science employs techniques and theories drawn from many fields within the broad areas of mathematics, statistics, information science, and computer science, including signal processing, probability models, machine learning, statistical learning, data mining, database, data engineering, pattern recognition and learning, visualization, predictive analytics, uncertainty modeling, data warehousing, data compression, computer programming, artificial intelligence, and high performance computing.',
#  u'Methods that scale to big data are of particular interest in data science, although the discipline is not generally considered to be restricted to such big data, and big data solutions are often focused on organizing and preprocessing the data instead of analysis.',
#  u'The development of machine learning has enhanced the growth and importance of data science.',
#  u'Data science affects academic and applied research in many domains, including machine translation, speech recognition, robotics, search engines, digital economy, but also the biological sciences, medical informatics, health care, social sciences and the humanities.',
#  u'It heavily influences economics, business and finance.',
#  u'From the business perspective, data science is an integral part of competitive intelligence, a newly emerging field that encompasses a number of activities, such as data mining and data analysis.',
#  u'[3] Data scientists use their data and analytical ability to find and interpret rich data sources; manage large amounts of data despite hardware, software, and bandwidth constraints; merge data sources; ensure consistency of datasets; create visualizations to aid in understanding data; build mathematical models using the data; and present and communicate the data insights/findings.',
#  u'They are often expected to produce answers in days rather than months, work by exploratory analysis and rapid iteration, and to produce and present results with dashboards (displays of current values) rather than papers/reports, as statisticians normally do.',
#  u'[4] "Data Scientist" has become a popular occupation with Harvard Business Review dubbing it "The Sexiest Job of the 21st Century" [5] and McKinsey & Company projecting a global excess demand of 1.5 million new data scientists.']

# %%
# tokenize into words
tokens = [word for word in nltk.word_tokenize(text)]
tokens[:1000]
# Out:
# [u'Data',
#  u'science',
#  u'is',
#  u'an',
#  u'interdisciplinary',
#  u'field',
#  u'about',
#  u'processes',
#  u'and',
#  u'systems',
#  u'to',
#  u'extract',
#  u'knowledge',
#  u'or',
#  u'insights',
#  u'from',
#  u'data',
#  u'in',
#  u'various',
#  u'forms',
#  u',',
#  u'either',
#  u'structured',
#  u'or',
#  u'unstructured',
#  u',',
#  u'[',
#  u'1',
#  u']',
#  u'[',
#  u'2',
#  u']',
#  u'which',
#  u'is',
#  u'a',
#  u'continuation',
#  u'of',
#  u'some',
#  u'of',
#  u'the',
#  u'data',
#  u'analysis',
#  u'fields',
#  u'such',
#  u'as',
#  u'statistics',
#  u',',
#  u'data',
#  u'mining',
#  u',',
#  u'and',
#  u'predictive',
#  u'analytics',
#  u',',
#  u'similar',
#  u'to',
#  u'Knowledge',
#  u'Discovery',
#  u'in',
#  u'Databases',
#  u'(',
#  u'KDD',
#  u')',
#  u'.',
#  u'Data',
#  u'science',
#  u'employs',
#  u'techniques',
#  u'and',
#  u'theories',
#  u'drawn',
#  u'from',
#  u'many',
#  u'fields',
#  u'within',
#  u'the',
#  u'broad',
#  u'areas',
#  u'of',
#  u'mathematics',
#  u',',
#  u'statistics',
#  u',',
#  u'information',
#  u'science',
#  u',',
#  u'and',
#  u'computer',
#  u'science',
#  u',',
#  u'including',
#  u'signal',
#  u'processing',
#  u',',
#  u'probability',
#  u'models',
#  u',',
#  u'machine',
#  u'learning',
#  u',',
#  u'statistical',
#  u'learning',
#  u',',
#  u'data',
#  u'mining',
#  u',',
#  u'database',
#  u',',
#  u'data',
#  u'engineering',
#  u',',
#  u'pattern',
#  u'recognition',
#  u'and',
#  u'learning',
#  u',',
#  u'visualization',
#  u',',
#  u'predictive',
#  u'analytics',
#  u',',
#  u'uncertainty',
#  u'modeling',
#  u',',
#  u'data',
#  u'warehousing',
#  u',',
#  u'data',
#  u'compression',
#  u',',
#  u'computer',
#  u'programming',
#  u',',
#  u'artificial',
#  u'intelligence',
#  u',',
#  u'and',
#  u'high',
#  u'performance',
#  u'computing',
#  u'.',
#  u'Methods',
#  u'that',
#  u'scale',
#  u'to',
#  u'big',
#  u'data',
#  u'are',
#  u'of',
#  u'particular',
#  u'interest',
#  u'in',
#  u'data',
#  u'science',
#  u',',
#  u'although',
#  u'the',
#  u'discipline',
#  u'is',
#  u'not',
#  u'generally',
#  u'considered',
#  u'to',
#  u'be',
#  u'restricted',
#  u'to',
#  u'such',
#  u'big',
#  u'data',
#  u',',
#  u'and',
#  u'big',
#  u'data',
#  u'solutions',
#  u'are',
#  u'often',
#  u'focused',
#  u'on',
#  u'organizing',
#  u'and',
#  u'preprocessing',
#  u'the',
#  u'data',
#  u'instead',
#  u'of',
#  u'analysis',
#  u'.',
#  u'The',
#  u'development',
#  u'of',
#  u'machine',
#  u'learning',
#  u'has',
#  u'enhanced',
#  u'the',
#  u'growth',
#  u'and',
#  u'importance',
#  u'of',
#  u'data',
#  u'science',
#  u'.',
#  u'Data',
#  u'science',
#  u'affects',
#  u'academic',
#  u'and',
#  u'applied',
#  u'research',
#  u'in',
#  u'many',
#  u'domains',
#  u',',
#  u'including',
#  u'machine',
#  u'translation',
#  u',',
#  u'speech',
#  u'recognition',
#  u',',
#  u'robotics',
#  u',',
#  u'search',
#  u'engines',
#  u',',
#  u'digital',
#  u'economy',
#  u',',
#  u'but',
#  u'also',
#  u'the',
#  u'biological',
#  u'sciences',
#  u',',
#  u'medical',
#  u'informatics',
#  u',',
#  u'health',
#  u'care',
#  u',',
#  u'social',
#  u'sciences',
#  u'and',
#  u'the',
#  u'humanities',
#  u'.',
#  u'It',
#  u'heavily',
#  u'influences',
#  u'economics',
#  u',',
#  u'business',
#  u'and',
#  u'finance',
#  u'.',
#  u'From',
#  u'the',
#  u'business',
#  u'perspective',
#  u',',
#  u'data',
#  u'science',
#  u'is',
#  u'an',
#  u'integral',
#  u'part',
#  u'of',
#  u'competitive',
#  u'intelligence',
#  u',',
#  u'a',
#  u'newly',
#  u'emerging',
#  u'field',
#  u'that',
#  u'encompasses',
#  u'a',
#  u'number',
#  u'of',
#  u'activities',
#  u',',
#  u'such',
#  u'as',
#  u'data',
#  u'mining',
#  u'and',
#  u'data',
#  u'analysis',
#  u'.',
#  u'[',
#  u'3',
#  u']',
#  u'Data',
#  u'scientists',
#  u'use',
#  u'their',
#  u'data',
#  u'and',
#  u'analytical',
#  u'ability',
#  u'to',
#  u'find',
#  u'and',
#  u'interpret',
#  u'rich',
#  u'data',
#  u'sources',
#  u';',
#  u'manage',
#  u'large',
#  u'amounts',
#  u'of',
#  u'data',
#  u'despite',
#  u'hardware',
#  u',',
#  u'software',
#  u',',
#  u'and',
#  u'bandwidth',
#  u'constraints',
#  u';',
#  u'merge',
#  u'data',
#  u'sources',
#  u';',
#  u'ensure',
#  u'consistency',
#  u'of',
#  u'datasets',
#  u';',
#  u'create',
#  u'visualizations',
#  u'to',
#  u'aid',
#  u'in',
#  u'understanding',
#  u'data',
#  u';',
#  u'build',
#  u'mathematical',
#  u'models',
#  u'using',
#  u'the',
#  u'data',
#  u';',
#  u'and',
#  u'present',
#  u'and',
#  u'communicate',
#  u'the',
#  u'data',
#  u'insights/findings',
#  u'.',
#  u'They',
#  u'are',
#  u'often',
#  u'expected',
#  u'to',
#  u'produce',
#  u'answers',
#  u'in',
#  u'days',
#  u'rather',
#  u'than',
#  u'months',
#  u',',
#  u'work',
#  u'by',
#  u'exploratory',
#  u'analysis',
#  u'and',
#  u'rapid',
#  u'iteration',
#  u',',
#  u'and',
#  u'to',
#  u'produce',
#  u'and',
#  u'present',
#  u'results',
#  u'with',
#  u'dashboards',
#  u'(',
#  u'displays',
#  u'of',
#  u'current',
#  u'values',
#  u')',
#  u'rather',
#  u'than',
#  u'papers/reports',
#  u',',
#  u'as',
#  u'statisticians',
#  u'normally',
#  u'do',
#  u'.',
#  u'[',
#  u'4',
#  u']',
#  u'``',
#  u'Data',
#  u'Scientist',
#  u"''",
#  u'has',
#  u'become',
#  u'a',
#  u'popular',
#  u'occupation',
#  u'with',
#  u'Harvard',
#  u'Business',
#  u'Review',
#  u'dubbing',
#  u'it',
#  u'``',
#  u'The',
#  u'Sexiest',
#  u'Job',
#  u'of',
#  u'the',
#  u'21st',
#  u'Century',
#  u"''",
#  u'[',
#  u'5',
#  u']',
#  u'and',
#  u'McKinsey',
#  u'&',
#  u'Company',
#  u'projecting',
#  u'a',
#  u'global',
#  u'excess',
#  u'demand',
#  u'of',
#  u'1.5',
#  u'million',
#  u'new',
#  u'data',
#  u'scientists',
#  u'.',
#  u'[',
#  u'6',
#  u']',
#  u'Universities',
#  u'are',
#  u'offering',
#  u'masters',
#  u'courses',
#  u'in',
#  u'data',
#  u'science',
#  u'.',
#  u'[',
#  u'7',
#  u']',
#  u'Shorter',
#  u'private',
#  u'bootcamps',
#  u'are',
#  u'also',
#  u'offering',
#  u'data',
#  u'science',
#  u'certificates',
#  u'including',
#  u'student-paid',
#  u'programs',
#  u'like',
#  u'General',
#  u'Assembly',
#  u'to',
#  u'employer-paid',
#  u'programs',
#  u'like',
#  u'The',
#  u'Data',
#  u'Incubator',
#  u'.',
#  u'[',
#  u'8',
#  u']',
#  u'The',
#  u'term',
#  u'``',
#  u'data',
#  u'science',
#  u"''",
#  u'(',
#  u'originally',
#  u'used',
#  u'interchangeably',
#  u'with',
#  u'``',
#  u'datalogy',
#  u"''",
#  u')',
#  u'has',
#  u'existed',
#  u'for',
#  u'over',
#  u'thirty',
#  u'years',
#  u'and',
#  u'was',
#  u'used',
#  u'initially',
#  u'as',
#  u'a',
#  u'substitute',
#  u'for',
#  u'computer',
#  u'science',
#  u'by',
#  u'Peter',
#  u'Naur',
#  u'in',
#  u'1960',
#  u'.',
#  u'In',
#  u'1974',
#  u',',
#  u'Naur',
#  u'published',
#  u'Concise',
#  u'Survey',
#  u'of',
#  u'Computer',
#  u'Methods',
#  u',',
#  u'which',
#  u'freely',
#  u'used',
#  u'the',
#  u'term',
#  u'data',
#  u'science',
#  u'in',
#  u'its',
#  u'survey',
#  u'of',
#  u'the',
#  u'contemporary',
#  u'data',
#  u'processing',
#  u'methods',
#  u'that',
#  u'are',
#  u'used',
#  u'in',
#  u'a',
#  u'wide',
#  u'range',
#  u'of',
#  u'applications',
#  u'.',
#  u'In',
#  u'1996',
#  u',',
#  u'members',
#  u'of',
#  u'the',
#  u'International',
#  u'Federation',
#  u'of',
#  u'Classification',
#  u'Societies',
#  u'(',
#  u'IFCS',
#  u')',
#  u'met',
#  u'in',
#  u'Kobe',
#  u'for',
#  u'their',
#  u'biennial',
#  u'conference',
#  u'.',
#  u'Here',
#  u',',
#  u'for',
#  u'the',
#  u'first',
#  u'time',
#  u',',
#  u'the',
#  u'term',
#  u'data',
#  u'science',
#  u'is',
#  u'included',
#  u'in',
#  u'the',
#  u'title',
#  u'of',
#  u'the',
#  u'conference',
#  u'(',
#  u'``',
#  u'Data',
#  u'Science',
#  u',',
#  u'classification',
#  u',',
#  u'and',
#  u'related',
#  u'methods',
#  u"''",
#  u')',
#  u'.',
#  u'[',
#  u'9',
#  u']',
#  u'In',
#  u'November',
#  u'1997',
#  u',',
#  u'C.F',
#  u'.',
#  u'Jeff',
#  u'Wu',
#  u'gave',
#  u'the',
#  u'inaugural',
#  u'lecture',
#  u'entitled',
#  u'``',
#  u'Statistics',
#  u'=',
#  u'Data',
#  u'Science',
#  u'?',
#  u'``',
#  u'[',
#  u'10',
#  u']',
#  u'for',
#  u'his',
#  u'appointment',
#  u'to',
#  u'the',
#  u'H.',
#  u'C.',
#  u'Carver',
#  u'Professorship',
#  u'at',
#  u'the',
#  u'University',
#  u'of',
#  u'Michigan',
#  u'.',
#  u'[',
#  u'11',
#  u']',
#  u'In',
#  u'this',
#  u'lecture',
#  u',',
#  u'he',
#  u'characterized',
#  u'statistical',
#  u'work',
#  u'as',
#  u'a',
#  u'trilogy',
#  u'of',
#  u'data',
#  u'collection',
#  u',',
#  u'data',
#  u'modeling',
#  u'and',
#  u'analysis',
#  u',',
#  u'and',
#  u'decision',
#  u'making',
#  u'.',
#  u'In',
#  u'his',
#  u'conclusion',
#  u',',
#  u'he',
#  u'initiated',
#  u'the',
#  u'modern',
#  u',',
#  u'non-computer',
#  u'science',
#  u',',
#  u'usage',
#  u'of',
#  u'the',
#  u'term',
#  u'``',
#  u'data',
#  u'science',
#  u"''",
#  u'and',
#  u'advocated',
#  u'that',
#  u'statistics',
#  u'be',
#  u'renamed',
#  u'data',
#  u'science',
#  u'and',
#  u'statisticians',
#  u'data',
#  u'scientists',
#  u'.',
#  u'[',
#  u'10',
#  u']',
#  u'Later',
#  u',',
#  u'he',
#  u'presented',
#  u'his',
#  u'lecture',
#  u'entitled',
#  u'``',
#  u'Statistics',
#  u'=',
#  u'Data',
#  u'Science',
#  u'?',
#  u"''",
#  u'as',
#  u'the',
#  u'first',
#  u'of',
#  u'his',
#  u'1998',
#  u'P.C',
#  u'.',
#  u'Mahalanobis',
#  u'Memorial',
#  u'Lectures',
#  u'.',
#  u'[',
#  u'12',
#  u']',
#  u'These',
#  u'lectures',
#  u'honor',
#  u'Prasanta',
#  u'Chandra',
#  u'Mahalanobis',
#  u',',
#  u'an',
#  u'Indian',
#  u'scientist',
#  u'and',
#  u'statistician',
#  u'and',
#  u'founder',
#  u'of',
#  u'the',
#  u'Indian',
#  u'Statistical',
#  u'Institute',
#  u'.',
#  u'In',
#  u'2001',
#  u',',
#  u'William',
#  u'S.',
#  u'Cleveland',
#  u'introduced',
#  u'data',
#  u'science',
#  u'as',
#  u'an',
#  u'independent',
#  u'discipline',
#  u',',
#  u'extending',
#  u'the',
#  u'field',
#  u'of',
#  u'statistics',
#  u'to',
#  u'incorporate',
#  u'``',
#  u'advances',
#  u'in',
#  u'computing',
#  u'with',
#  u'data',
#  u"''",
#  u'in',
#  u'his',
#  u'article',
#  u'``',
#  u'Data',
#  u'Science',
#  u':',
#  u'An',
#  u'Action',
#  u'Plan',
#  u'for',
#  u'Expanding',
#  u'the',
#  u'Technical',
#  u'Areas',
#  u'of',
#  u'the',
#  u'Field',
#  u'of',
#  u'Statistics',
#  u',',
#  u"''",
#  u'which',
#  u'was',
#  u'published',
#  u'in',
#  u'Volume',
#  u'69',
#  u',',
#  u'No',
#  u'.',
#  u'1',
#  u',',
#  u'of',
#  u'the',
#  u'April',
#  u'2001',
#  u'edition',
#  u'of',
#  u'the',
#  u'International',
#  u'Statistical',
#  u'Review',
#  u'/',
#  u'Revue',
#  u'Internationale',
#  u'de',
#  u'Statistique',
#  u'.',
#  u'[',
#  u'13',
#  u']',
#  u'In',
#  u'his',
#  u'report',
#  u',',
#  u'Cleveland',
#  u'establishes',
#  u'six',
#  u'technical',
#  u'areas',
#  u'which',
#  u'he',
#  u'believed',
#  u'to',
#  u'encompass',
#  u'the',
#  u'field',
#  u'of',
#  u'data',
#  u'science',
#  u':',
#  u'multidisciplinary',
#  u'investigations',
#  u',',
#  u'models',
#  u'and',
#  u'methods',
#  u'for',
#  u'data',
#  u',',
#  u'computing',
#  u'with',
#  u'data',
#  u',',
#  u'pedagogy',
#  u',',
#  u'tool',
#  u'evaluation',
#  u',',
#  u'and',
#  u'theory',
#  u'.',
#  u'In',
#  u'April',
#  u'2002',
#  u',',
#  u'the',
#  u'International',
#  u'Council',
#  u'for',
#  u'Science',
#  u':',
#  u'Committee',
#  u'on',
#  u'Data',
#  u'for',
#  u'Science',
#  u'and',
#  u'Technology',
#  u'(',
#  u'CODATA',
#  u')',
#  u'[',
#  u'14',
#  u']',
#  u'started',
#  u'the',
#  u'Data',
#  u'Science',
#  u'Journal',
#  u',',
#  u'[',
#  u'15',
#  u']',
#  u'a',
#  u'publication',
#  u'focused',
#  u'on',
#  u'issues',
#  u'such',
#  u'as',
#  u'the',
#  u'description',
#  u'of',
#  u'data',
#  u'systems',
#  u',',
#  u'their',
#  u'publication',
#  u'on',
#  u'the',
#  u'internet',
#  u',',
#  u'applications',
#  u'and',
#  u'legal',
#  u'issues',
#  u'.',
#  u'[',
#  u'16',
#  u']',
#  u'Shortly',
#  u'thereafter',
#  u',',
#  u'in',
#  u'January',
#  u'2003',
#  u',',
#  u'Columbia',
#  u'University',
#  u'began',
#  u'publishing',
#  u'The',
#  u'Journal',
#  u'of',
#  u'Data',
#  u'Science',
#  u',',
#  u'[',
#  u'17',
#  u']',
#  u'which',
#  u'provided',
#  u'a',
#  u'platform',
#  u'for',
#  u'all',
#  u'data',
#  u'workers',
#  u'to',
#  u'present',
#  u'their',
#  u'views',
#  u'and',
#  u'exchange',
#  u'ideas',
#  u'.',
#  u'The',
#  u'journal',
#  u'was',
#  u'largely',
#  u'devoted',
#  u'to',
#  u'the',
#  u'application',
#  u'of',
#  u'statistical',
#  u'methods',
#  u'and',
#  u'quantitative',
#  u'research',
#  u'.',
#  u'In',
#  u'2005',
#  u',']

# %%
# only keep tokens that start with a letter (using regular expressions)
import re
clean_tokens = [token for token in tokens if re.search('^[a-zA-Z]+', token)]
clean_tokens[:100]
# Out:
# [u'Data',
#  u'science',
#  u'is',
#  u'an',
#  u'interdisciplinary',
#  u'field',
#  u'about',
#  u'processes',
#  u'and',
#  u'systems',
#  u'to',
#  u'extract',
#  u'knowledge',
#  u'or',
#  u'insights',
#  u'from',
#  u'data',
#  u'in',
#  u'various',
#  u'forms',
#  u'either',
#  u'structured',
#  u'or',
#  u'unstructured',
#  u'which',
#  u'is',
#  u'a',
#  u'continuation',
#  u'of',
#  u'some',
#  u'of',
#  u'the',
#  u'data',
#  u'analysis',
#  u'fields',
#  u'such',
#  u'as',
#  u'statistics',
#  u'data',
#  u'mining',
#  u'and',
#  u'predictive',
#  u'analytics',
#  u'similar',
#  u'to',
#  u'Knowledge',
#  u'Discovery',
#  u'in',
#  u'Databases',
#  u'KDD',
#  u'Data',
#  u'science',
#  u'employs',
#  u'techniques',
#  u'and',
#  u'theories',
#  u'drawn',
#  u'from',
#  u'many',
#  u'fields',
#  u'within',
#  u'the',
#  u'broad',
#  u'areas',
#  u'of',
#  u'mathematics',
#  u'statistics',
#  u'information',
#  u'science',
#  u'and',
#  u'computer',
#  u'science',
#  u'including',
#  u'signal',
#  u'processing',
#  u'probability',
#  u'models',
#  u'machine',
#  u'learning',
#  u'statistical',
#  u'learning',
#  u'data',
#  u'mining',
#  u'database',
#  u'data',
#  u'engineering',
#  u'pattern',
#  u'recognition',
#  u'and',
#  u'learning',
#  u'visualization',
#  u'predictive',
#  u'analytics',
#  u'uncertainty',
#  u'modeling',
#  u'data',
#  u'warehousing',
#  u'data',
#  u'compression',
#  u'computer']

# %%
# count the tokens
from collections import Counter
c = Counter(clean_tokens)

c.most_common(25)       # mixed case
# Out:
# [(u'and', 54),
#  (u'data', 50),
#  (u'the', 47),
#  (u'of', 39),
#  (u'science', 24),
#  (u'in', 22),
#  (u'to', 19),
#  (u'Data', 18),
#  (u'a', 16),
#  (u'In', 13),
#  (u'Science', 12),
#  (u'for', 11),
#  (u'as', 10),
#  (u'is', 10),
#  (u'term', 8),
#  (u'on', 8),
#  (u'The', 7),
#  (u'his', 7),
#  (u'are', 7),
#  (u'analysis', 6),
#  (u'was', 6),
#  (u'scientists', 5),
#  (u'such', 5),
#  (u'their', 5),
#  (u'that', 5)]

# %%
sorted(c.items())[:25]  # counts similar words separately
for item in sorted(c.items())[:25]:
    print item[0], item[1]
# Out:
# Action 1
# Advanced 2
# Although 1
# American 1
# An 1
# Analytics 3
# April 2
# Areas 1
# Assembly 1
# Association 1
# Board 1
# Business 1
# C. 1
# C.F 1
# CODATA 1
# Carver 1
# Century 2
# Chandra 1
# Classification 1
# Cleveland 2
# Collections 1
# Columbia 1
# Committee 1
# Company 1
# Computer 1

# %%
###################
##### EXERCISE ####
###################

# Put each word in clean_tokens in lower case
print(clean_tokens.lower())
# find the new word count of the lowered tokens
# Then show the top 10 words used in this corpus
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-837344c1caa2> in <module>()
#       4
#       5 # Put each word in clean_tokens in lower case
# ----> 6 print(clean_tokens.lower())
#       7 # find the new word count of the lowered tokens
#       8 # Then show the top 10 words used in this corpus
#
# AttributeError: 'list' object has no attribute 'lower'

# %% [markdown]
# ###Stemming
# What:  Reduce a word to its base/stem form
#
# Why:   Often makes sense to treat multiple word forms the same way
#
# Notes: Uses a "simple" and fast rule-based approach
#        Output can be undesirable for irregular words
#        Stemmed words are usually not shown to users (used for analysis/indexing)
#        Some search engines treat words with the same stem as synonyms

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')

# %%
# example stemming
stemmer.stem('charge')
stemmer.stem('charging')
stemmer.stem('charged')
# Out:
# u'charg'

# %%
# stem the tokens
stemmed_tokens = [stemmer.stem(t) for t in clean_tokens]
# Out:
# [u'data',
#  u'scienc',
#  u'is',
#  u'an',
#  u'interdisciplinari',
#  u'field',
#  u'about',
#  u'process',
#  u'and',
#  u'system',
#  u'to',
#  u'extract',
#  u'knowledg',
#  u'or',
#  u'insight',
#  u'from',
#  u'data',
#  u'in',
#  u'various',
#  u'form',
#  u'either',
#  u'structur',
#  u'or',
#  u'unstructur',
#  u'which',
#  u'is',
#  u'a',
#  u'continu',
#  u'of',
#  u'some',
#  u'of',
#  u'the',
#  u'data',
#  u'analysi',
#  u'field',
#  u'such',
#  u'as',
#  u'statist',
#  u'data',
#  u'mine',
#  u'and',
#  u'predict',
#  u'analyt',
#  u'similar',
#  u'to',
#  u'knowledg',
#  u'discoveri',
#  u'in',
#  u'databas',
#  u'kdd',
#  u'data',
#  u'scienc',
#  u'employ',
#  u'techniqu',
#  u'and',
#  u'theori',
#  u'drawn',
#  u'from',
#  u'mani',
#  u'field',
#  u'within',
#  u'the',
#  u'broad',
#  u'area',
#  u'of',
#  u'mathemat',
#  u'statist',
#  u'inform',
#  u'scienc',
#  u'and',
#  u'comput',
#  u'scienc',
#  u'includ',
#  u'signal',
#  u'process',
#  u'probabl',
#  u'model',
#  u'machin',
#  u'learn',
#  u'statist',
#  u'learn',
#  u'data',
#  u'mine',
#  u'databas',
#  u'data',
#  u'engin',
#  u'pattern',
#  u'recognit',
#  u'and',
#  u'learn',
#  u'visual',
#  u'predict',
#  u'analyt',
#  u'uncertainti',
#  u'model',
#  u'data',
#  u'wareh',
#  u'data',
#  u'compress',
#  u'comput',
#  u'program',
#  u'artifici',
#  u'intellig',
#  u'and',
#  u'high',
#  u'perform',
#  u'comput',
#  u'method',
#  u'that',
#  u'scale',
#  u'to',
#  u'big',
#  u'data',
#  u'are',
#  u'of',
#  u'particular',
#  u'interest',
#  u'in',
#  u'data',
#  u'scienc',
#  u'although',
#  u'the',
#  u'disciplin',
#  u'is',
#  u'not',
#  u'general',
#  u'consid',
#  u'to',
#  u'be',
#  u'restrict',
#  u'to',
#  u'such',
#  u'big',
#  u'data',
#  u'and',
#  u'big',
#  u'data',
#  u'solut',
#  u'are',
#  u'often',
#  u'focus',
#  u'on',
#  u'organ',
#  u'and',
#  u'preprocess',
#  u'the',
#  u'data',
#  u'instead',
#  u'of',
#  u'analysi',
#  u'the',
#  u'develop',
#  u'of',
#  u'machin',
#  u'learn',
#  u'has',
#  u'enhanc',
#  u'the',
#  u'growth',
#  u'and',
#  u'import',
#  u'of',
#  u'data',
#  u'scienc',
#  u'data',
#  u'scienc',
#  u'affect',
#  u'academ',
#  u'and',
#  u'appli',
#  u'research',
#  u'in',
#  u'mani',
#  u'domain',
#  u'includ',
#  u'machin',
#  u'translat',
#  u'speech',
#  u'recognit',
#  u'robot',
#  u'search',
#  u'engin',
#  u'digit',
#  u'economi',
#  u'but',
#  u'also',
#  u'the',
#  u'biolog',
#  u'scienc',
#  u'medic',
#  u'informat',
#  u'health',
#  u'care',
#  u'social',
#  u'scienc',
#  u'and',
#  u'the',
#  u'human',
#  u'it',
#  u'heavili',
#  u'influenc',
#  u'econom',
#  u'busi',
#  u'and',
#  u'financ',
#  u'from',
#  u'the',
#  u'busi',
#  u'perspect',
#  u'data',
#  u'scienc',
#  u'is',
#  u'an',
#  u'integr',
#  u'part',
#  u'of',
#  u'competit',
#  u'intellig',
#  u'a',
#  u'newli',
#  u'emerg',
#  u'field',
#  u'that',
#  u'encompass',
#  u'a',
#  u'number',
#  u'of',
#  u'activ',
#  u'such',
#  u'as',
#  u'data',
#  u'mine',
#  u'and',
#  u'data',
#  u'analysi',
#  u'data',
#  u'scientist',
#  u'use',
#  u'their',
#  u'data',
#  u'and',
#  u'analyt',
#  u'abil',
#  u'to',
#  u'find',
#  u'and',
#  u'interpret',
#  u'rich',
#  u'data',
#  u'sourc',
#  u'manag',
#  u'larg',
#  u'amount',
#  u'of',
#  u'data',
#  u'despit',
#  u'hardwar',
#  u'softwar',
#  u'and',
#  u'bandwidth',
#  u'constraint',
#  u'merg',
#  u'data',
#  u'sourc',
#  u'ensur',
#  u'consist',
#  u'of',
#  u'dataset',
#  u'creat',
#  u'visual',
#  u'to',
#  u'aid',
#  u'in',
#  u'understand',
#  u'data',
#  u'build',
#  u'mathemat',
#  u'model',
#  u'use',
#  u'the',
#  u'data',
#  u'and',
#  u'present',
#  u'and',
#  u'communic',
#  u'the',
#  u'data',
#  u'insights/find',
#  u'they',
#  u'are',
#  u'often',
#  u'expect',
#  u'to',
#  u'produc',
#  u'answer',
#  u'in',
#  u'day',
#  u'rather',
#  u'than',
#  u'month',
#  u'work',
#  u'by',
#  u'exploratori',
#  u'analysi',
#  u'and',
#  u'rapid',
#  u'iter',
#  u'and',
#  u'to',
#  u'produc',
#  u'and',
#  u'present',
#  u'result',
#  u'with',
#  u'dashboard',
#  u'display',
#  u'of',
#  u'current',
#  u'valu',
#  u'rather',
#  u'than',
#  u'papers/report',
#  u'as',
#  u'statistician',
#  u'normal',
#  u'do',
#  u'data',
#  u'scientist',
#  u'has',
#  u'becom',
#  u'a',
#  u'popular',
#  u'occup',
#  u'with',
#  u'harvard',
#  u'busi',
#  u'review',
#  u'dub',
#  u'it',
#  u'the',
#  u'sexiest',
#  u'job',
#  u'of',
#  u'the',
#  u'centuri',
#  u'and',
#  u'mckinsey',
#  u'compani',
#  u'project',
#  u'a',
#  u'global',
#  u'excess',
#  u'demand',
#  u'of',
#  u'million',
#  u'new',
#  u'data',
#  u'scientist',
#  u'univers',
#  u'are',
#  u'offer',
#  u'master',
#  u'cours',
#  u'in',
#  u'data',
#  u'scienc',
#  u'shorter',
#  u'privat',
#  u'bootcamp',
#  u'are',
#  u'also',
#  u'offer',
#  u'data',
#  u'scienc',
#  u'certif',
#  u'includ',
#  u'student-paid',
#  u'program',
#  u'like',
#  u'general',
#  u'assembl',
#  u'to',
#  u'employer-paid',
#  u'program',
#  u'like',
#  u'the',
#  u'data',
#  u'incub',
#  u'the',
#  u'term',
#  u'data',
#  u'scienc',
#  u'origin',
#  u'use',
#  u'interchang',
#  u'with',
#  u'datalog',
#  u'has',
#  u'exist',
#  u'for',
#  u'over',
#  u'thirti',
#  u'year',
#  u'and',
#  u'was',
#  u'use',
#  u'initi',
#  u'as',
#  u'a',
#  u'substitut',
#  u'for',
#  u'comput',
#  u'scienc',
#  u'by',
#  u'peter',
#  u'naur',
#  u'in',
#  u'in',
#  u'naur',
#  u'publish',
#  u'concis',
#  u'survey',
#  u'of',
#  u'comput',
#  u'method',
#  u'which',
#  u'freeli',
#  u'use',
#  u'the',
#  u'term',
#  u'data',
#  u'scienc',
#  u'in',
#  u'it',
#  u'survey',
#  u'of',
#  u'the',
#  u'contemporari',
#  u'data',
#  u'process',
#  u'method',
#  u'that',
#  u'are',
#  u'use',
#  u'in',
#  u'a',
#  u'wide',
#  u'rang',
#  u'of',
#  u'applic',
#  u'in',
#  u'member',
#  u'of',
#  u'the',
#  u'intern',
#  u'feder',
#  u'of',
#  u'classif',
#  u'societi',
#  u'ifc',
#  u'met',
#  u'in',
#  u'kobe',
#  u'for',
#  u'their',
#  u'biennial',
#  u'confer',
#  u'here',
#  u'for',
#  u'the',
#  u'first',
#  u'time',
#  u'the',
#  u'term',
#  u'data',
#  u'scienc',
#  u'is',
#  u'includ',
#  u'in',
#  u'the',
#  u'titl',
#  u'of',
#  u'the',
#  u'confer',
#  u'data',
#  u'scienc',
#  u'classif',
#  u'and',
#  u'relat',
#  u'method',
#  u'in',
#  u'novemb',
#  u'c.f',
#  u'jeff',
#  u'wu',
#  u'gave',
#  u'the',
#  u'inaugur',
#  u'lectur',
#  u'entitl',
#  u'statist',
#  u'data',
#  u'scienc',
#  u'for',
#  u'his',
#  u'appoint',
#  u'to',
#  u'the',
#  u'h.',
#  u'c.',
#  u'carver',
#  u'professorship',
#  u'at',
#  u'the',
#  u'univers',
#  u'of',
#  u'michigan',
#  u'in',
#  u'this',
#  u'lectur',
#  u'he',
#  u'character',
#  u'statist',
#  u'work',
#  u'as',
#  u'a',
#  u'trilog',
#  u'of',
#  u'data',
#  u'collect',
#  u'data',
#  u'model',
#  u'and',
#  u'analysi',
#  u'and',
#  u'decis',
#  u'make',
#  u'in',
#  u'his',
#  u'conclus',
#  u'he',
#  u'initi',
#  u'the',
#  u'modern',
#  u'non-comput',
#  u'scienc',
#  u'usag',
#  u'of',
#  u'the',
#  u'term',
#  u'data',
#  u'scienc',
#  u'and',
#  u'advoc',
#  u'that',
#  u'statist',
#  u'be',
#  u'renam',
#  u'data',
#  u'scienc',
#  u'and',
#  u'statistician',
#  u'data',
#  u'scientist',
#  u'later',
#  u'he',
#  u'present',
#  u'his',
#  u'lectur',
#  u'entitl',
#  u'statist',
#  u'data',
#  u'scienc',
#  u'as',
#  u'the',
#  u'first',
#  u'of',
#  u'his',
#  u'p.c',
#  u'mahalanobi',
#  u'memori',
#  u'lectur',
#  u'these',
#  u'lectur',
#  u'honor',
#  u'prasanta',
#  u'chandra',
#  u'mahalanobi',
#  u'an',
#  u'indian',
#  u'scientist',
#  u'and',
#  u'statistician',
#  u'and',
#  u'founder',
#  u'of',
#  u'the',
#  u'indian',
#  u'statist',
#  u'institut',
#  u'in',
#  u'william',
#  u's.',
#  u'cleveland',
#  u'introduc',
#  u'data',
#  u'scienc',
#  u'as',
#  u'an',
#  u'independ',
#  u'disciplin',
#  u'extend',
#  u'the',
#  u'field',
#  u'of',
#  u'statist',
#  u'to',
#  u'incorpor',
#  u'advanc',
#  u'in',
#  u'comput',
#  u'with',
#  u'data',
#  u'in',
#  u'his',
#  u'articl',
#  u'data',
#  u'scienc',
#  u'an',
#  u'action',
#  u'plan',
#  u'for',
#  u'expand',
#  u'the',
#  u'technic',
#  u'area',
#  u'of',
#  u'the',
#  u'field',
#  u'of',
#  u'statist',
#  u'which',
#  u'was',
#  u'publish',
#  u'in',
#  u'volum',
#  u'no',
#  u'of',
#  u'the',
#  u'april',
#  u'edit',
#  u'of',
#  u'the',
#  u'intern',
#  u'statist',
#  u'review',
#  u'revu',
#  u'international',
#  u'de',
#  u'statistiqu',
#  u'in',
#  u'his',
#  u'report',
#  u'cleveland',
#  u'establish',
#  u'six',
#  u'technic',
#  u'area',
#  u'which',
#  u'he',
#  u'believ',
#  u'to',
#  u'encompass',
#  u'the',
#  u'field',
#  u'of',
#  u'data',
#  u'scienc',
#  u'multidisciplinari',
#  u'investig',
#  u'model',
#  u'and',
#  u'method',
#  u'for',
#  u'data',
#  u'comput',
#  u'with',
#  u'data',
#  u'pedagogi',
#  u'tool',
#  u'evalu',
#  u'and',
#  u'theori',
#  u'in',
#  u'april',
#  u'the',
#  u'intern',
#  u'council',
#  u'for',
#  u'scienc',
#  u'committe',
#  u'on',
#  u'data',
#  u'for',
#  u'scienc',
#  u'and',
#  u'technolog',
#  u'codata',
#  u'start',
#  u'the',
#  u'data',
#  u'scienc',
#  u'journal',
#  u'a',
#  u'public',
#  u'focus',
#  u'on',
#  u'issu',
#  u'such',
#  u'as',
#  u'the',
#  u'descript',
#  u'of',
#  u'data',
#  u'system',
#  u'their',
#  u'public',
#  u'on',
#  u'the',
#  u'internet',
#  u'applic',
#  u'and',
#  u'legal',
#  u'issu',
#  u'short',
#  u'thereaft',
#  u'in',
#  u'januari',
#  u'columbia',
#  u'univers',
#  u'began',
#  u'publish',
#  u'the',
#  u'journal',
#  u'of',
#  u'data',
#  u'scienc',
#  u'which',
#  u'provid',
#  u'a',
#  u'platform',
#  u'for',
#  u'all',
#  u'data',
#  u'worker',
#  u'to',
#  u'present',
#  u'their',
#  u'view',
#  u'and',
#  u'exchang',
#  u'idea',
#  u'the',
#  u'journal',
#  u'was',
#  u'larg',
#  u'devot',
#  u'to',
#  u'the',
#  u'applic',
#  u'of',
#  u'statist',
#  u'method',
#  u'and',
#  u'quantit',
#  u'research',
#  u'in',
#  u'the',
#  u'nation',
#  u'scienc',
#  u'board',
#  u'publish',
#  u'long-liv',
#  u'digit',
#  u'data',
#  u'collect',
#  u'enabl',
#  u'research',
#  u'and',
#  u'educ',
#  u'in',
#  u'the',
#  u'centuri',
#  u'defin',
#  u'data',
#  u'scientist',
#  u'as',
#  u'the',
#  u'inform',
#  u'and',
#  u'comput',
#  u'scientist',
#  u'databas',
#  u'and',
#  u'softwar',
#  u'and',
#  u'programm',
#  u'disciplinari',
#  u'expert',
#  u'curat',
#  u'and',
#  u'expert',
#  u'annot',
#  u'librarian',
#  u'archivist',
#  u'and',
#  u'other',
#  u'who',
#  u'are',
#  u'crucial',
#  u'to',
#  u'the',
#  u'success',
#  u'manag',
#  u'of',
#  u'a',
#  u'digit',
#  u'data',
#  u'collect',
#  u'whose',
#  u'primari',
#  u'activ',
#  u'is',
#  u'to',
#  u'conduct',
#  u'creativ',
#  u'inquiri',
#  u'and',
#  u'analysi',
#  u'in',
#  u'the',
#  u'ieee',
#  u'task',
#  u'forc',
#  u'on',
#  u'data',
#  u'scienc',
#  u'and',
#  u'advanc',
#  u'analyt',
#  u'was',
#  u'launch',
#  u'and',
#  u'the',
#  u'first',
#  u'intern',
#  u'confer',
#  u'ieee',
#  u'intern',
#  u'confer',
#  u'on',
#  u'data',
#  u'scienc',
#  u'and',
#  u'advanc',
#  u'analyt',
#  u'was',
#  u'launch',
#  u'in',
#  u'in',
#  u'the',
#  u'intern',
#  u'journal',
#  u'on',
#  u'data',
#  u'scienc',
#  u'and',
#  u'analyt',
#  u'was',
#  u'launch',
#  u'by',
#  u'springer',
#  u'to',
#  u'publish',
#  u'origin',
#  u'work',
#  u'on',
#  u'data',
#  u'scienc',
#  u'and',
#  u'big',
#  u'data',
#  u'analyt',
#  u'in',
#  u'citat',
#  u'need',
#  u'dj',
#  u'patil',
#  u'and',
#  u'jeff',
#  u'hammerbach',
#  u'use',
#  u'the',
#  u'term',
#  u'data',
#  u'scientist',
#  u'to',
#  u'defin',
#  u'their',
#  u'job',
#  u'at',
#  u'linkedin',
#  u'and',
#  u'facebook',
#  u'respect',
#  u'although',
#  u'use',
#  u'of',
#  u'the',
#  u'term',
#  u'data',
#  u'scienc',
#  u'has',
#  u'explod',
#  u'in',
#  u'busi',
#  u'environ',
#  u'mani',
#  u'academ',
#  u'and',
#  u'journalist',
#  u'see',
#  u'no',
#  u'distinct',
#  u'between',
#  u'data',
#  u'scienc',
#  u'and',
#  u'statist',
#  u'write',
#  u'in',
#  u'forb',
#  u'gil',
#  u'press',
#  u'argu',
#  u'that',
#  u'data',
#  u'scienc',
#  u'is',
#  u'a',
#  u'buzzword',
#  u'without',
#  u'a',
#  u'clear',
#  u'definit',
#  u'and',
#  u'has',
#  u'simpli',
#  u'replac',
#  u'analytics\u201d',
#  u'in',
#  u'context',
#  u'such',
#  u'as',
#  u'graduat',
#  u'degre',
#  u'program',
#  u'in',
#  u'the',
#  u'question-and-answ',
#  u'section',
#  u'of',
#  u'his',
#  u'keynot',
#  u'address',
#  u'at',
#  u'the',
#  u'joint',
#  u'statist',
#  u'meet',
#  u'of',
#  u'american',
#  u'statist',
#  u'associ',
#  u'note',
#  u'appli',
#  u'statistician',
#  u'nate',
#  u'silver',
#  u'said',
#  u'think',
#  u'data-scientist',
#  u'is',
#  u'a',
#  u'sex',
#  u'up',
#  u'term',
#  u'for',
#  u'a',
#  u'statistician',
#  ...]

# %%
# count the stemmed tokens
c = Counter(stemmed_tokens)
c.most_common(25)       # all lowercase
sorted(c.items())[:25]  # some are strange
# Out:
# [(u'a', 16),
#  (u'abil', 1),
#  (u'about', 1),
#  (u'academ', 2),
#  (u'action', 1),
#  (u'activ', 2),
#  (u'address', 1),
#  (u'advanc', 3),
#  (u'advoc', 1),
#  (u'affect', 1),
#  (u'aid', 1),
#  (u'all', 1),
#  (u'also', 2),
#  (u'although', 2),
#  (u'american', 1),
#  (u'amount', 1),
#  (u'an', 5),
#  (u'analysi', 6),
#  (u'analyt', 7),
#  (u'analytics\u201d', 1),
#  (u'and', 54),
#  (u'annot', 1),
#  (u'answer', 1),
#  (u'appli', 2),
#  (u'applic', 3)]

# %% [markdown]
# ###Lemmatization
# What:  Derive the canonical form ('lemma') of a word
#
# Why:   Can be better than stemming, reduces words to a 'normal' form.
#
# Notes: Uses a dictionary-based approach (slower than stemming)

# %%
lemmatizer = nltk.WordNetLemmatizer()

# compare stemmer to lemmatizer
stemmer.stem('dogs')
lemmatizer.lemmatize('dogs')
# Out:
# u'dog'

# %%
stemmer.stem('wolves') # Beter for information retrieval and search
lemmatizer.lemmatize('wolves') # Better for text analysis
# Out:
# u'wolf'

# %%
stemmer.stem('is')
lemmatizer.lemmatize('is')
lemmatizer.lemmatize('is',pos='v')
# Out:
# u'be'

# %% [markdown]
# ###Part of Speech Tagging
#
# What:  Determine the part of speech of a word
#
# Why:   This can inform other methods and models such as Named Entity Recognition
#
# Notes: http://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %%
temp_sent = 'Sinan and Patrick and Liam are great teachers!'
# pos_tag takes a tokenize sentence
nltk.pos_tag(nltk.word_tokenize(temp_sent))
# Out:
# [('Sinan', 'NNP'),
#  ('and', 'CC'),
#  ('Patrick', 'NNP'),
#  ('and', 'CC'),
#  ('Liam', 'NNP'),
#  ('are', 'VBP'),
#  ('great', 'JJ'),
#  ('teachers', 'NNS'),
#  ('!', '.')]

# %%
temp_sent = 'Ian and Alasdair are teaching at General Assembly this Monday!'
# pos_tag takes a tokenize sentence
nltk.pos_tag(nltk.word_tokenize(temp_sent))
# Out:
# [('Ian', 'NNP'),
#  ('and', 'CC'),
#  ('Alasdair', 'NNP'),
#  ('are', 'VBP'),
#  ('teaching', 'VBG'),
#  ('at', 'IN'),
#  ('General', 'NNP'),
#  ('Assembly', 'NNP'),
#  ('this', 'DT'),
#  ('Monday', 'NNP'),
#  ('!', '.')]

# %% [markdown]
# ###Stopword Removal
#
# What:  Remove common words that will likely appear in any text
#
# Why:   They don't tell you much about your text

# %%
# most of top 25 stemmed tokens are "worthless"
c.most_common(25)
# Out:
# [(u'data', 68),
#  (u'and', 54),
#  (u'the', 54),
#  (u'of', 39),
#  (u'scienc', 38),
#  (u'in', 35),
#  (u'to', 19),
#  (u'a', 16),
#  (u'statist', 15),
#  (u'for', 11),
#  (u'is', 10),
#  (u'as', 10),
#  (u'scientist', 9),
#  (u'use', 8),
#  (u'term', 8),
#  (u'comput', 8),
#  (u'on', 8),
#  (u'analyt', 7),
#  (u'his', 7),
#  (u'are', 7),
#  (u'field', 7),
#  (u'method', 6),
#  (u'intern', 6),
#  (u'was', 6),
#  (u'analysi', 6)]

# %%
# view the list of stopwords
stopwords = nltk.corpus.stopwords.words('english')
sorted(stopwords)
# Out:
# [u'a',
#  u'about',
#  u'above',
#  u'after',
#  u'again',
#  u'against',
#  u'ain',
#  u'all',
#  u'am',
#  u'an',
#  u'and',
#  u'any',
#  u'are',
#  u'aren',
#  u'as',
#  u'at',
#  u'be',
#  u'because',
#  u'been',
#  u'before',
#  u'being',
#  u'below',
#  u'between',
#  u'both',
#  u'but',
#  u'by',
#  u'can',
#  u'couldn',
#  u'd',
#  u'did',
#  u'didn',
#  u'do',
#  u'does',
#  u'doesn',
#  u'doing',
#  u'don',
#  u'down',
#  u'during',
#  u'each',
#  u'few',
#  u'for',
#  u'from',
#  u'further',
#  u'had',
#  u'hadn',
#  u'has',
#  u'hasn',
#  u'have',
#  u'haven',
#  u'having',
#  u'he',
#  u'her',
#  u'here',
#  u'hers',
#  u'herself',
#  u'him',
#  u'himself',
#  u'his',
#  u'how',
#  u'i',
#  u'if',
#  u'in',
#  u'into',
#  u'is',
#  u'isn',
#  u'it',
#  u'its',
#  u'itself',
#  u'just',
#  u'll',
#  u'm',
#  u'ma',
#  u'me',
#  u'mightn',
#  u'more',
#  u'most',
#  u'mustn',
#  u'my',
#  u'myself',
#  u'needn',
#  u'no',
#  u'nor',
#  u'not',
#  u'now',
#  u'o',
#  u'of',
#  u'off',
#  u'on',
#  u'once',
#  u'only',
#  u'or',
#  u'other',
#  u'our',
#  u'ours',
#  u'ourselves',
#  u'out',
#  u'over',
#  u'own',
#  u're',
#  u's',
#  u'same',
#  u'shan',
#  u'she',
#  u'should',
#  u'shouldn',
#  u'so',
#  u'some',
#  u'such',
#  u't',
#  u'than',
#  u'that',
#  u'the',
#  u'their',
#  u'theirs',
#  u'them',
#  u'themselves',
#  u'then',
#  u'there',
#  u'these',
#  u'they',
#  u'this',
#  u'those',
#  u'through',
#  u'to',
#  u'too',
#  u'under',
#  u'until',
#  u'up',
#  u've',
#  u'very',
#  u'was',
#  u'wasn',
#  u'we',
#  u'were',
#  u'weren',
#  u'what',
#  u'when',
#  u'where',
#  u'which',
#  u'while',
#  u'who',
#  u'whom',
#  u'why',
#  u'will',
#  u'with',
#  u'won',
#  u'wouldn',
#  u'y',
#  u'you',
#  u'your',
#  u'yours',
#  u'yourself',
#  u'yourselves']

# %%
##################
### Exercise  ####
##################


# Create a variable called stemmed_stops which is the 
# stemmed version of each stopword in stopwords
# Use the stemmer we used up above!

# Then create a list called stemmed_tokens_no_stop that 
# contains only the tokens in stemmed_tokens that aren't in 
# stemmed_stops

# Show the 25 most common stemmed non stop word tokens

# %% [markdown]
# ###Named Entity Recognition
#
# What:  Automatically extract the names of people, places, organizations, etc.
#
# Why:   Can help you to identify "important" words
#
# Notes: Training NER classifier requires a lot of annotated training data
#        Should be trained on data relevant to your task
#        Stanford NER classifier is the "gold standard"

# %%
sentence = 'Ian is an instructor for General Assembly'

tokenized = nltk.word_tokenize(sentence)

tokenized
# Out:
# ['Ian', 'is', 'an', 'instructor', 'for', 'General', 'Assembly']

# %%
tagged = nltk.pos_tag(tokenized)

tagged
# Out:
# [('Ian', 'NNP'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('instructor', 'NN'),
#  ('for', 'IN'),
#  ('General', 'NNP'),
#  ('Assembly', 'NNP')]

# %%
chunks = nltk.ne_chunk(tagged)

chunks
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /Users/LouisTsang/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#     340             if method is not None:
# --> 341                 return method()
#     342             return None
#     343         else:
#
# /Users/LouisTsang/anaconda/lib/python2.7/site-packages/nltk/tree.pyc in _repr_png_(self)
#     724             _canvas_frame.print_to_file(in_path)
#     725             _canvas_frame.destroy_widget(widget)
# --> 726             subprocess.call([find_binary('gs', binary_names=['gswin32c.exe', 'gswin64c.exe'], env_vars=['PATH'], verbose=False)] +
#     727                             '-q -dEPSCrop -sDEVICE=png16m -r90 -dTextAlphaBits=4 -dGraphicsAlphaBits=4 -dSAFER -dBATCH -dNOPAUSE -sOutputFile={0:} {1:}'
#     728                             .format(out_path, in_path).split())
#
# /Users/LouisTsang/anaconda/lib/python2.7/site-packages/nltk/__init__.pyc in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     600                 binary_names=None, url=None, verbose=True):
#     601     return next(find_binary_iter(name, path_to_bin, env_vars, searchpath,
# --> 602                                  binary_names, url, verbose))
#     603
#     604 def find_jar_iter(name_pattern, path_to_jar=None, env_vars=(),
#
# /Users/LouisTsang/anaconda/lib/python2.7/site-packages/nltk/__init__.pyc in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     594     """
#     595     for file in  find_file_iter(path_to_bin or name, env_vars, searchpath, binary_names,
# --> 596                      url, verbose):
#     597         yield file
#     598
#
# /Users/LouisTsang/anaconda/lib/python2.7/site-packages/nltk/__init__.pyc in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     565                         (filename, url))
#     566         div = '='*75
# --> 567         raise LookupError('\n\n%s\n%s\n%s' % (div, msg, div))
#     568
#     569
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
# Tree('S', [Tree('GPE', [('Ian', 'NNP')]), ('is', 'VBZ'), ('an', 'DT'), ('instructor', 'NN'), ('for', 'IN'), Tree('ORGANIZATION', [('General', 'NNP'), ('Assembly', 'NNP')])])

# %%
def extract_entities(text):
    entities = []
    # tokenize into sentences
    for sentence in nltk.sent_tokenize(text):
        # tokenize sentences into words
        # add part-of-speech tags
        # use NLTK's NER classifier
        chunks = nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sentence)))
        # parse the results
        entities.extend([chunk for chunk in chunks if hasattr(chunk, 'label')])
    return entities

for entity in extract_entities('Ian is an instructor for General Assembly'):
    print '[' + entity.label() + '] ' + ' '.join(c[0] for c in entity.leaves())
# Out:
# [GPE] Ian
# [ORGANIZATION] General Assembly

# %% [markdown]
# ###Term Frequency - Inverse Document Frequency (TF-IDF)
#
# What:  Computes "relative frequency" that a word appears in a document
#            compared to its frequency across all documents
#
# Why:   More useful than "term frequency" for identifying "important" words in
#            each document (high frequency in that document, low frequency in
#            other documents)
#
# Notes: Used for search engine scoring, text summarization, document clustering
#
# How:
#     TF(t) = (Number of times term t appears in a document) / (Total number of terms in the document).
#     IDF(t) = log_e(Total number of documents / Number of documents with term t in it).

# %%
sample = ['Bob likes sports', 'Bob hates sports', 'Bob likes likes trees']

import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

vect = CountVectorizer()

# %%
# Each row represents a sentence
# Each column represents a word
vect.fit_transform(sample).toarray()
vect.get_feature_names()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
tfidf.fit_transform(sample).toarray()
tfidf.get_feature_names()

# %%
# the IDF of each word
idf = tfidf.idf_
print dict(zip(tfidf.get_feature_names(), idf))

# %%
###############
## Exercise ###
###############


# for each sentence in sample, find the most "interesting 
#words" by ordering their tfidf in ascending order

# %% [markdown]
# ###LDA - Latent Dirichlet Allocation
#
# What:  Way of automatically discovering topics from sentences
#
# Why:   Much quicker than manually creating and identifying topic clusters

# %%
import lda

# Instantiate a count vectorizer with two additional parameters
vect = CountVectorizer(stop_words='english', ngram_range=[1,3]) 
sentences_train = vect.fit_transform(sentences)

# %%
# Instantiate an LDA model
model = lda.LDA(n_topics=10, n_iter=500)
model.fit(sentences_train) # Fit the model 
n_top_words = 10
topic_word = model.topic_word_
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vect.get_feature_names())[np.argsort(topic_dist)][:-n_top_words:-1]
    print('Topic {}: {}'.format(i, ', '.join(topic_words)))

# %%
# EXAMPLE: Automatically summarize a document


# corpus of 2000 movie reviews
from nltk.corpus import movie_reviews
reviews = [movie_reviews.raw(filename) for filename in movie_reviews.fileids()]

# %%
# create document-term matrix
tfidf = TfidfVectorizer(stop_words='english')
dtm = tfidf.fit_transform(reviews)
features = tfidf.get_feature_names()

# %%
import numpy as np

# %%
# find the most and least "interesting" sentences in a randomly selected review
def summarize():
    
    # choose a random movie review    
    review_id = np.random.randint(0, len(reviews))
    review_text = reviews[review_id]

    # we are going to score each sentence in the review for "interesting-ness"
    sent_scores = []
    # tokenize document into sentences
    for sentence in nltk.sent_tokenize(review_text):
        # exclude short sentences
        if len(sentence) > 6:
            score = 0
            token_count = 0
            # tokenize sentence into words
            tokens = nltk.word_tokenize(sentence)
            # compute sentence "score" by summing TFIDF for each word
            for token in tokens:
                if token in features:
                    score += dtm[review_id, features.index(token)]
                    token_count += 1
            # divide score by number of tokens
            sent_scores.append((score / float(token_count + 1), sentence))

    # lowest scoring sentences
    print '\nLOWEST:\n'
    for sent_score in sorted(sent_scores)[:3]:
        print sent_score[1]

    # highest scoring sentences
    print '\nHIGHEST:\n'
    for sent_score in sorted(sent_scores, reverse=True)[:3]:
        print sent_score[1]

# try it out!
summarize()

# %%
# TextBlob Demo: "Simplified Text Processing"
# Installation: pip install textblob
! pip install textblob

# %%
from textblob import TextBlob, Word

# %%
# identify words and noun phrases
blob = TextBlob('Liam and Sinan are instructors for General Assembly')
blob.words
blob.noun_phrases

# %%
# sentiment analysis
blob = TextBlob('I hate this horrible movie. This movie is not very good.')
blob.sentences
blob.sentiment.polarity
[sent.sentiment.polarity for sent in blob.sentences]

# %%
# sentiment subjectivity
TextBlob("I am a cool person").sentiment.subjectivity # Pretty subjective
TextBlob("I am a person").sentiment.subjectivity # Pretty objective
# different scores for essentially the same sentence
print TextBlob('Ian and Alasdair are instructors for General Assembly in Sydney').sentiment.subjectivity

# %%
# singularize and pluralize
blob = TextBlob('Put away the dishes.')
[word.singularize() for word in blob.words]

# %%
[word.pluralize() for word in blob.words]

# %%
# spelling correction
blob = TextBlob('15 minuets late')
blob.correct()

# %%
# spellcheck
Word('parot').spellcheck()

# %%
# definitions
Word('bank').define()
Word('bank').define('v')

# %%
# translation and language identification
blob = TextBlob('Welcome to the classroom.')
blob.translate(to='es')
blob = TextBlob('Hola amigos')
blob.detect_language()
